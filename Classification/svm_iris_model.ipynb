# %%
import pandas as pd
from sklearn.datasets import load_iris
flower  = load_iris()

# %%
dir(flower)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df  =pd.DataFrame(flower.data,columns=flower.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['target'] = flower.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df['flower_name'] = df.target.apply(lambda x : flower.target_names[x]) #'df.target.replace({0:'setosa',1:'versicolor',2:'virginica'})''
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target flower_name
# ...

# %%
d1 = df[df.target==0]
d2 = df[df.target==1]
d3 = df[df.target==2]

# %%
import matplotlib.pyplot as plt
plt.scatter(d1['sepal length (cm)'],d1['sepal width (cm)'],color='red',marker='+')
plt.scatter(d2['sepal length (cm)'],d2['sepal width (cm)'],color='blue',marker='*')
plt.scatter(d3['sepal length (cm)'],d3['sepal width (cm)'],color='green')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
plt.scatter(d2['sepal length (cm)'],d2['sepal width (cm)'],color='blue',marker='*')
plt.scatter(d3['sepal length (cm)'],d3['sepal width (cm)'],color='green')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
plt.scatter(d1['sepal length (cm)'],d1['sepal width (cm)'],color='red',marker='+')
plt.scatter(d2['sepal length (cm)'],d2['sepal width (cm)'],color='blue',marker='*')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
plt.scatter(d3['sepal length (cm)'],d3['sepal width (cm)'],color='green')
plt.scatter(d1['sepal length (cm)'],d1['sepal width (cm)'],color='red',marker='+')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
plt.scatter(d1['petal length (cm)'],d1['petal width (cm)'],color='red',marker='+')
plt.scatter(d2['petal length (cm)'],d2['petal width (cm)'],color='blue',marker='*')
plt.scatter(d3['petal length (cm)'],d3['petal width (cm)'],color='green')
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
# Out:
# Text(0, 0.5, 'petal width (cm)')

# %%
plt.scatter(d2['petal length (cm)'],d2['petal width (cm)'],color='blue',marker='*')
plt.scatter(d3['petal length (cm)'],d3['petal width (cm)'],color='green')
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
# Out:
# Text(0, 0.5, 'petal width (cm)')

# %%
plt.scatter(d1['petal length (cm)'],d1['petal width (cm)'],color='red',marker='+')
plt.scatter(d2['petal length (cm)'],d2['petal width (cm)'],color='blue',marker='*')
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
# Out:
# Text(0, 0.5, 'petal width (cm)')

# %%
plt.scatter(d1['petal length (cm)'],d1['petal width (cm)'],color='red',marker='+')
plt.scatter(d3['petal length (cm)'],d3['petal width (cm)'],color='green')
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
# Out:
# Text(0, 0.5, 'petal width (cm)')

# %%
 from sklearn.model_selection import train_test_split as tts

# %%
x = df.drop(['target','flower_name'],axis=1)
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y=df.target

# %%
x_train,x_test,y_train,y_test = tts(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC
model = SVC( kernel='rbf')

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667
